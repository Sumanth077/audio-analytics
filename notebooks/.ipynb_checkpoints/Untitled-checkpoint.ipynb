# %%
from pathlib import Path
import pandas as pd
import base64

# %%
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", None)

# %%
from steamship import Steamship, Plugin, PluginInstance, File

# %%
BLOCKIFIER_HANDLE = "amazon-s2t-blockifier"
TAGGER_HANDLE = "oneai-tagger"

client = Steamship(profile="test")

blockifier_instance = PluginInstance.create(
    client,
    plugin_handle=BLOCKIFIER_HANDLE,
    config={
        "aws_access_key_id": "AKIAYRUKYC4IP4SV2WFM",
        "aws_secret_access_key": "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",
        "aws_s3_bucket_name": "enias",
        "aws_region": "us-west-2",
        "speaker_detection": True, 
        "n_speakers": 2
    },
).data

tagger_instance = PluginInstance.create(
    client,
    plugin_handle=TAGGER_HANDLE,
    config={
        "api_key": "84ae4e01-e565-4791-a30c-181534f3eef4",
        "skills": "highlights",
        "input_type": "auto-detect",
    },
).data

# %% [markdown]
# ## 1. Create the audio file

# %%
audio_path = Path(".").parent / "test_small.mp3"
with audio_path.open("rb") as f:
    audio_file_b64 = base64.b64encode(f.read())

decoded = base64.b64decode(audio_file_b64)

file = File.create(
    client, filename=str(audio_path.resolve()), mime_type="audio/mp3"
).data

# %% [markdown]
# ## 2. Blockify the audio file using Amazon Transcribe

# %%
file.blockify(plugin_instance=blockifier_instance.handle).wait(
    max_timeout_s=300, retry_delay_s=30
)
file = file_b64.refresh().data

transcript = file_b64.blocks[0].text
transcript

# %% [markdown]
# ## 3. Summarize the audio transcript using OneAI

# %%
from steamship import Block

# %%
file = File.create(client=client, blocks=[Block.CreateRequest(text=text)]).data

# %%
file.tag(plugin_instance=tagger_instance.handle).wait()

# %%
file = file.refresh().data

# %%
file.blocks[0].tags
# Out:
# [Tag(client=None, id='020219D7-01DE-49F0-8472-019B9930BFA5', file_id='3149FA12-01E4-4985-A716-543271580D3C', block_id='AC078A21-72B7-4FE2-89B0-54DB6C4C0439', kind='highlights', name='highlight', value=None, start_idx=45667, end_idx=45846),
#  Tag(client=None, id='02B7CEFC-7674-4DBD-B49E-22E68F672AF3', file_id='3149FA12-01E4-4985-A716-543271580D3C', block_id='AC078A21-72B7-4FE2-89B0-54DB6C4C0439', kind='highlights', name='highlight', value=None, start_idx=72639, end_idx=72851),
#  Tag(client=None, id='0533B568-331C-477F-8F2A-F118B10F6196', file_id='3149FA12-01E4-4985-A716-543271580D3C', block_id='AC078A21-72B7-4FE2-89B0-54DB6C4C0439', kind='highlights', name='highlight', value=None, start_idx=75226, end_idx=75251),
#  Tag(client=None, id='066CD98E-77A3-447A-9EEA-C16808E6D4FD', file_id='3149FA12-01E4-4985-A716-543271580D3C', block_id='AC078A21-72B7-4FE2-89B0-54DB6C4C0439', kind='highlights', name='highlight', value=None, start_idx=40586, end_idx=40618),
# ...

# %%
df = pd.DataFrame(tag.dict() for tag in file.blocks[0].tags)[
    ["kind", "name", "start_idx", "end_idx"]
]
df["phrase"] = df.apply(lambda x: transcript[x["start_idx"] : x["end_idx"]], axis=1)
df
# Out:
#            kind       name  start_idx  end_idx  \
# 0    highlights  highlight      45667    45846
# 1    highlights  highlight      72639    72851
# 2    highlights  highlight      75226    75251
# 3    highlights  highlight      40586    40618
# 4    highlights  highlight      24734    24851
# 5    highlights  highlight      45028    45420
# 6    highlights  highlight      83956    84119
# 7    highlights  highlight      53903    54057
# 8    highlights  highlight      57917    58005
# 9    highlights  highlight      16105    16813
# 10   highlights  highlight      57800    57916
# 11   highlights  highlight      53831    53902
# 12   highlights  highlight        621      892
# 13   highlights  highlight      27671    27743
# 14   highlights  highlight      42369    42419
# 15   highlights  highlight      34440    34569
# 16   highlights  highlight      58828    58908
# 17   highlights  highlight      22606    22917
# 18   highlights  highlight      26409    26482
# ...
